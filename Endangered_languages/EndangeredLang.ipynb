# %%
import numpy as np
import pandas as pd

# %%
# This dataset records many endangered languages around the world. 
# The goal of this analysis is to find out whether "Telugu" is an endangered language in India.

# %%
data=pd.read_csv('Data/endangeredLang.csv')

# %%
list(data)
# Out:
# ['ID',
#  'Name in English',
#  'Countries',
#  'Country codes alpha 3',
#  'Degree of endangerment',
#  'Number of speakers',
#  'Latitude',
#  'Longitude',
#  'Description of the location']

# %%
data[['Countries','Name in English']].head(6)
# Out:
#                                            Countries Name in English
# 0                                              Italy   South Italian
# 1                                              Italy        Sicilian
# 2  Germany, Denmark, Netherlands, Poland, Russian...       Low Saxon
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...      Belarusian
# 4                                 Italy, Switzerland         Lombard
# 5  Albania, Germany, Austria, Belarus, Bosnia and...          Romani

# %%
data.groupby(['Degree of endangerment']).count()
# Out:
#                          ID  Name in English  Countries  \
# Degree of endangerment
# Critically endangered   607              607        607
# Definitely endangered   680              680        679
# Extinct                 253              253        253
# Severely endangered     554              554        554
# Vulnerable              628              628        628
#
#                         Country codes alpha 3  Number of speakers  Latitude  \
# Degree of endangerment
# Critically endangered                     607                 544       606
# Definitely endangered                     679                 635       680
# Extinct                                   253                 244       252
# Severely endangered                       554                 505       554
# Vulnerable                                628                 611       627
#
#                         Longitude  Description of the location
# Degree of endangerment
# ...

# %%
data['Degree of endangerment'].value_counts()
# Out:
# Definitely endangered    680
# Vulnerable               628
# Critically endangered    607
# Severely endangered      554
# Extinct                  253
# Name: Degree of endangerment, dtype: int64

# %%
data[(data.Countries == 'India')& (data["Name in English"].str.startswith("T"))]
# Out:
#         ID Name in English Countries Country codes alpha 3  \
# 18    1585            Tulu     India                   IND
# 128   1161           Thado     India                   IND
# 146   1154        Tangkhul     India                   IND
# 279   1104          Tangsa     India                   IND
# 330    979           Tagin     India                   IND
# 370   1173            Tiwa     India                   IND
# 737   1216            Turi     India                   IND
# 869   1201   Takahanyilang     India                   IND
# 998   1222       Tai Phake     India                   IND
# 1144  1575            Toda     India                   IND
# 1216   448            Toto     India                   IND
# 1249   562           Tarao     India                   IND
# 1799  1223        Tai Nora     India                   IND
# 1800  1224        Tai Rong     India                   IND
# 1801  1220          Tangam     India                   IND
# ...
